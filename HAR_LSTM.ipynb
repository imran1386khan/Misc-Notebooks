# %%
# Importing Libraries

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.4MB 4.7MB/s
# ...
#      |████████████████████████████████| 460kB 26.5MB/s
# ...
#      |████████████████████████████████| 112kB 36.5MB/s
# ...
#      |████████████████████████████████| 102kB 11.3MB/s
# ...
#      |████████████████████████████████| 102kB 11.3MB/s
# ...
#      |████████████████████████████████| 71kB 9.1MB/s
# ...
#      |████████████████████████████████| 71kB 9.6MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6489 sha256=a7d14d7bb7410cbc067e10c9d9c90f6709dcbae004e725fef2bb9115c12900e6
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# ...
#   Created wheel for gql: filename=gql-0.2.0-cp36-none-any.whl size=7630 sha256=237a5a45269393400d9f6c93e1696871c4f0b159dbce2fed9c2398e254214eb4
#   Stored in directory: /root/.cache/pip/wheels/ce/0e/7b/58a8a5268655b3ad74feef5aa97946f0addafb3cbb6bd2da23
# ...

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://app.wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ddc60b791657c8b364b2b14593b47970d81060a4
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Successfully logged in to Weights & Biases!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/Inertial Signals_train.zip'
# !unzip '/content/drive/My Drive/Inertial Signals_test.zip'
# Out:
# Archive:  /content/drive/My Drive/Inertial Signals_train.zip
#    creating: Inertial Signals/
#   inflating: Inertial Signals/body_gyro_z_train.txt
#    creating: __MACOSX/
#    creating: __MACOSX/Inertial Signals/
#   inflating: __MACOSX/Inertial Signals/._body_gyro_z_train.txt
#   inflating: Inertial Signals/body_acc_y_train.txt
#   inflating: __MACOSX/Inertial Signals/._body_acc_y_train.txt
#   inflating: Inertial Signals/y_train.txt
#   inflating: __MACOSX/Inertial Signals/._y_train.txt
#   inflating: Inertial Signals/total_acc_z_train.txt
#   inflating: __MACOSX/Inertial Signals/._total_acc_z_train.txt
#   inflating: Inertial Signals/body_acc_x_train.txt
#   inflating: __MACOSX/Inertial Signals/._body_acc_x_train.txt
#   inflating: Inertial Signals/body_gyro_x_train.txt
#   inflating: __MACOSX/Inertial Signals/._body_gyro_x_train.txt
#   inflating: Inertial Signals/total_acc_y_train.txt
#   inflating: __MACOSX/Inertial Signals/._total_acc_y_train.txt
# ...

# %%
import pandas as pd
import numpy as np

# %%
wandb.init()
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/konvicted1386/uncategorized" target="_blank">https://app.wandb.ai/konvicted1386/uncategorized</a><br/>
#                 Run page: <a href="https://app.wandb.ai/konvicted1386/uncategorized/runs/36r7yvh6" target="_blank">https://app.wandb.ai/konvicted1386/uncategorized/runs/36r7yvh6</a><br/>
# W&B Run: https://app.wandb.ai/konvicted1386/uncategorized/runs/36r7yvh6

# %%
# !wandb sweep sweep.yaml
# Out:
# wandb: Creating sweep from: sweep.yaml
# wandb: Created sweep with ID: ohs0oh0u
# wandb: View sweep at: https://app.wandb.ai/konvicted1386/uncategorized/sweeps/ohs0oh0u
# wandb: Run sweep agent with: wandb agent konvicted1386/uncategorized/ohs0oh0u

# %%
# !wandb agent ohs0oh0u
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-03-29 04:16:48,978 - wandb.wandb_agent - INFO - Running runs: []
# 2020-03-29 04:16:49,157 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-03-29 04:16:49,157 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	epochs: 30
# 	hidden_layer_size: 64
# 	learning-rate: 0.005149803079201993
# 	optimizer: adam
# 2020-03-29 04:16:49,161 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python /content/HAR_LSTM.ipynb --epochs=30 --hidden_layer_size=64 --learning-rate=0.005149803079201993 --optimizer=adam
# python3: can't open file '/content/HAR_LSTM.ipynb': [Errno 2] No such file or directory
# 2020-03-29 04:16:54,170 - wandb.wandb_agent - INFO - Running runs: ['u0akqi1d']
# 2020-03-29 04:16:54,170 - wandb.wandb_agent - INFO - Cleaning up finished run: u0akqi1d
# 2020-03-29 04:16:54,347 - wandb.wandb_agent - INFO - Agent received command: run
# ...

# %%
# !pwd
# Out:
# /content

# %%
# Activities are the class labels
# It is a 6 class classification
ACTIVITIES = {
    0: 'WALKING',
    1: 'WALKING_UPSTAIRS',
    2: 'WALKING_DOWNSTAIRS',
    3: 'SITTING',
    4: 'STANDING',
    5: 'LAYING',
}

# Utility function to print the confusion matrix
def confusion_matrix(Y_true, Y_pred):
    Y_true = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_true, axis=1)])
    Y_pred = pd.Series([ACTIVITIES[y] for y in np.argmax(Y_pred, axis=1)])

    return pd.crosstab(Y_true, Y_pred, rownames=['True'], colnames=['Pred'])

# %% [markdown]
# ### Data

# %%
# Data directory
DATADIR = '/content/Inertial Signals'

# %%
# Raw data signals
# Signals are from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = f'{DATADIR}/{signal}_{subset}.txt'
        signals_data.append(
            _read_csv(filename).as_matrix()
        ) 
    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
exp1 = np.ones((9, 7552, 128))
np.transpose(exp1, (1,2,0)).shape
# Out:
# (7552, 128, 9)

# %%
# df = pd.read_csv(f'/content/Inertial Signals/body_acc_x_test.txt', delim_whitespace=True, header=None)
# pd.get_dummies(df[0])
# df

# %%
def load_y(subset):
    """
    The objective that we are trying to predict is a integer, from 1 to 6,
    that represents a human activity. We return a binary representation of 
    every sample objective as a 6 bits vector using One Hot Encoding
    (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)
    """
    filename = f'{DATADIR}/y_{subset}.txt'
    y = _read_csv(filename)[0]

    return pd.get_dummies(y).as_matrix()

# %%
def load_data():
    """
    Obtain the dataset from multiple files.
    Returns: X_train, X_test, y_train, y_test
    """
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')

    return X_train, X_test, y_train, y_test

# %%
# Importing tensorflow
np.random.seed(42)
import tensorflow as tf
# tf.set_random_seed(42)
tf.random.set_seed(42)

# %%
# Configuring a session
session_conf = tf.config.threading.set_inter_op_parallelism_threads(
    1
)

# %%
# Import Keras
from keras import backend as K
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph())
K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
# Importing libraries
# from tensorflow.python.keras.models import Sequential
# from tensorflow.python.keras.layers import LSTM
# from tensorflow.python.keras.layers.core import Dense, Dropout
# from tensorflow.python.keras.callbacks import EarlyStopping

# Models
import tensorflow
from tensorflow import keras
from keras import backend as K
from keras import regularizers
from keras.models import Sequential, model_from_json
# from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.layers import LSTM, Dense, Flatten, Conv2D, BatchNormalization, Dropout, MaxPooling2D, Activation
from keras.optimizers import RMSprop, SGD, Adam, Nadam
from keras import callbacks
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, Callback, EarlyStopping

# %%
# from keras.callbacks import EarlyStopping

# %%
# Initializing parameters
epochs = 30
batch_size = 16
n_hidden = 32

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Loading the train and test data
X_train, X_test, Y_train, Y_test = load_data()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
X_train.shape
# Out:
# (7352, 128, 9)

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %%
# import wandb
# from wandb.keras import WandbCallback

# %%
# sweep_config = {
#    'method': 'random',
#    'parameters': {
#        'learning-rate': {
#            'min': 0.00001,
#            'max': 0.1
#        },
#        'optimizer': {
#            'values': ["nadam", "rmsprop", "adagrad"]
#        },
#        'layers': {
#            'values': [32, 64, 96, 128]
#        }
#    }
# }

# %%
# Initialize a new sweep
# Arguments:
#     – sweep_config: the sweep config dictionary defined above
#     – entity: Set the username for the sweep
#     – project: Set the project name for the sweep
# sweep_id = wandb.sweep(sweep_config, entity="sweep", project="simpsons")
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Create sweep with ID: cei7m3xg
# Sweep URL: https://app.wandb.ai/sweep/simpsons/sweeps/cei7m3xg

# %%
# Default values for hyper-parameters we're going to sweep over
# config_defaults = {
#         'epochs': 30,
#         'batch_size': 16,
#         'layers': 32,
#         # 'weight_decay': 0.0005,
#         'learning_rate': 1e-3,
#         'activation': 'relu',
#         'optimizer': 'nadam',
#         'seed': 42
#     }

# # Initialize a new wandb run
# wandb.init(config=config_defaults)

# # Config is a variable that holds and saves hyperparameters and inputs
# config = wandb.config
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/sweep/simpsons" target="_blank">https://app.wandb.ai/sweep/simpsons</a><br/>
#                 Run page: <a href="https://app.wandb.ai/sweep/simpsons/runs/aec5e45m" target="_blank">https://app.wandb.ai/sweep/simpsons/runs/aec5e45m</a><br/>

# %% [markdown]
# - Defining the Architecture of LSTM

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(n_hidden, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='relu'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 32)                5376
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 198
# ...
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Training the model

# callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model.fit(X_train,
          Y_train,
          batch_size=batch_size,
          validation_data=(X_test, Y_test),
          epochs=epochs
          # callback=[WandbCallback(validation_data=(X_test, Y_test), labels=ACTIVITIES)]
          )
model.save("har_lstm.h5")

# [WandbCallback(data_type="image", validation_data=(X_test, y_test), labels=ACTIVITIES),
#                                    keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)])
# Out:
# Epoch 1/30
# 460/460 [==============================] - 291s 632ms/step - loss: 1.3609 - accuracy: 0.4513
# Epoch 2/30
# 460/460 [==============================] - 285s 620ms/step - loss: 1.6059 - accuracy: 0.5147
# Epoch 3/30
# 460/460 [==============================] - 284s 617ms/step - loss: 2.2774 - accuracy: 0.4442
# Epoch 4/30
# 460/460 [==============================] - 282s 614ms/step - loss: 1.3008 - accuracy: 0.4710
# Epoch 5/30
# 460/460 [==============================] - 284s 617ms/step - loss: 1.2023 - accuracy: 0.5239
# Epoch 6/30
# 460/460 [==============================] - 285s 621ms/step - loss: 1.1059 - accuracy: 0.5754
# Epoch 7/30
# 460/460 [==============================] - 286s 621ms/step - loss: 1.0112 - accuracy: 0.6050
# Epoch 8/30
# 460/460 [==============================] - 287s 625ms/step - loss: 1.1843 - accuracy: 0.5694
# Epoch 9/30
# 460/460 [==============================] - 284s 617ms/step - loss: 1.0025 - accuracy: 0.6096
# Epoch 10/30
# ...

# %%
# Confusion Matrix
confusion_matrix(Y_test, model.predict(X_test))
# Out:
# Pred                LAYING  SITTING  ...  WALKING_DOWNSTAIRS  WALKING_UPSTAIRS
# True                                 ...
# LAYING                 510        0  ...                   0                27
# SITTING                  0      373  ...                   0                 0
# STANDING                 0       74  ...                   0                 0
# WALKING                  0        0  ...                  27                 0
# WALKING_DOWNSTAIRS       0        0  ...                 414                 3
# WALKING_UPSTAIRS         0        0  ...                   6               446
#
# [6 rows x 6 columns]

# %%
# Confusion Matrix
confusion_matrix(Y_test, model.predict(X_test))
# Out:
# Pred                LAYING  SITTING  ...  WALKING_DOWNSTAIRS  WALKING_UPSTAIRS
# True                                 ...
# LAYING                 505        5  ...                   0                 1
# SITTING                  1      420  ...                   0                 0
# STANDING                 0      121  ...                   0                 0
# WALKING                  0        2  ...                   3                 5
# WALKING_DOWNSTAIRS       0        0  ...                 398                20
# WALKING_UPSTAIRS         0        9  ...                   3               446
#
# [6 rows x 6 columns]

# %%
score = model.evaluate(X_test, Y_test)
# Out:
# 2947/2947 [==============================] - 6s 2ms/step

# %%
score
# Out:
# [0.33798534475541364, 0.9056667797760435]

# %% [markdown]
# - With a simple 2 layer architecture we got 90.09% accuracy and a loss of 0.30
# - We can further imporve the performace with Hyperparameter tuning
