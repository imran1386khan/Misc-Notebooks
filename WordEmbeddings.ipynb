# %%
import numpy as np

# %%
# !wget -P /root/input/ -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2019-10-03 10:53:30--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.145.13
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.145.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/x-gzip]
# Saving to: ‘/root/input/GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  79.9MB/s    in 4m 39s
#
# 2019-10-03 10:58:09 (5.64 MB/s) - ‘/root/input/GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
# !pip install gensim
from gensim.models import KeyedVectors

# %%
EMBEDDING_FILE = '/root/input/GoogleNews-vectors-negative300.bin.gz' # from above
word2vec = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
len(word2vec.vocab)
# Out:
# 3000000

# %%
# Example
word2vec["cat"].shape
# Out:
# (300,)

# %%
word2vec.most_similar(positive=['cooking', 'potatos'], topn=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('Slow_cooker', 0.698670506477356),
#  ('cook', 0.6981996297836304),
#  ('Spaghetti_squash', 0.682273268699646),
#  ('Crock_pot', 0.6749206781387329),
#  ('stir_fry_vegetables', 0.6731513738632202)]

# %%
word2vec.most_similar(positive=['germany', 'france'], topn=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('europe', 0.7222039699554443)]

# %%
word2vec.doesnt_match("potatoes milk cake sweets bean kidney wallnut computer".split())
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'computer'

# %%
word2vec.most_similar(positive=['king', 'woman'], negative=['man'], topn=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('queen', 0.7118192911148071), ('monarch', 0.6189674139022827)]

# %%
word2vec.similarity('princess', 'queen')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.7070532

# %%
# Addind our own word embedings

# %%
# !pip install detectormorse
# Out:
# ...
#      |████████████████████████████████| 337kB 2.8MB/s
# ...
#   Created wheel for detectormorse: filename=DetectorMorse-0.4.1-cp36-none-any.whl size=337577 sha256=fe7c50edd71efe98e675a6386e0e95326926eb375ab588027b5d7119e8d62e93
#   Stored in directory: /root/.cache/pip/wheels/9e/b2/64/3291ab26036b1cf36c7bcca1e9b631b7ece2bacf4c953ca62c
# ...
#   Created wheel for nlup: filename=nlup-0.8-cp36-none-any.whl size=17686 sha256=74df8be7b2d4691e3b69f45af2d6e6e3d6db9e5bbfc1dd1a433042b8fe7732dc
#   Stored in directory: /root/.cache/pip/wheels/b7/21/d3/82d9447310b2d3c522641e9303397bf0fcacd666d5746a20d8
# Successfully built detectormorse nlup
# ...

# %%
import detectormorse
dm = detectormorse.default_model()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-dfdf2dd6a49e> in <module>()
#       1 import detectormorse
# ----> 2 dm = detectormorse.default_model()
#
# AttributeError: module 'detectormorse' has no attribute 'default_model'

# %%
detector.default_model()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ade1cbd6ccfe> in <module>()
# ----> 1 detector.default_model()
#
# AttributeError: module 'detectormorse' has no attribute 'default_model'
